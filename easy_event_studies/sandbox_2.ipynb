# %%
from easy_event_studies import *
import pdb

# %%
results = run_event_study(
    ticker='UBS',
    event_date='2024-01-03',
    estimation_window=[-250, 0],
    event_window=[0, 10]
)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plot_CAR_over_time(results, '2024-01-03')
